# %%
import nltk
from nltk.tokenize import *
from nltk.corpus import *
from nltk.stem import *
import re

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Keshav
# [nltk_data]     Kalani\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Keshav
# [nltk_data]     Kalani\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Keshav
# [nltk_data]     Kalani\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Keshav Kalani\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text = "Hello, I am Keshav Kalani. I am a third year computer undergraduate at MESWCOE. I live in Pune. For more information contact me!!"

# %%
# Sentence Tokenization
var1 = sent_tokenize(text)
print("Sentence Tokenization:")
print(var1)
# Out:
# Sentence Tokenization:
# ['Hello, I am Keshav Kalani.', 'I am a third year computer undergraduate at MESWCOE.', 'I live in Pune.', 'For more information contact me!', '!']

# %%
# Word Tokenization
var2 = word_tokenize(text)
print("\nWord Tokenization:")
print(var2)
# Out:
# Word Tokenization:
# ['Hello', ',', 'I', 'am', 'Keshav', 'Kalani', '.', 'I', 'am', 'a', 'third', 'year', 'computer', 'undergraduate', 'at', 'MESWCOE', '.', 'I', 'live', 'in', 'Pune', '.', 'For', 'more', 'information', 'contact', 'me', '!', '!']

# %%
# Removing Punctuation
text = re.sub('[^a-zA-Z]', ' ', text)
print("\nAfter Removing Punctuation:")
print(text)
# Out:
# After Removing Punctuation:
# Hello  I am Keshav Kalani  I am a third year computer undergraduate at MESWCOE  I live in Pune  For more information contact me

# %%
# Removing Stopwords
var3 = set(stopwords.words('english'))
tokens = word_tokenize(text.lower())
filtered_text = []
for word in tokens:
    if word not in var3:
        filtered_text.append(word)
print("\nFiltered Sentence:")
print(filtered_text)
# Out:
# Filtered Sentence:
# ['hello', 'keshav', 'kalani', 'third', 'year', 'computer', 'undergraduate', 'meswcoe', 'live', 'pune', 'information', 'contact']

# %%
# Stemming
print("\nStemming:")
words = ["write", "writing", "wrote", "writes", "reading", "reads"]
ps = PorterStemmer()
for w in words:
    print(ps.stem(w))
# Out:
# Stemming:
# write
# write
# wrote
# write
# read
# read

# %%
# Lemmatization
print("\nLemmatization:")
wordnet_lemmatizer = WordNetLemmatizer()
text2 = "studies studying cries cry"
tt = nltk.word_tokenize(text2)
for w in tt:
    print("Lemma for {} is {}".format(
        w,
        wordnet_lemmatizer.lemmatize(w)
    ))
# Out:
# Lemmatization:
# Lemma for studies is study
# Lemma for studying is studying
# Lemma for cries is cry
# Lemma for cry is cry

# %%
# POS Tagging
print("\nPOS Tagging:")
text3 = "Hello everyone this is a sample text Earth"
text3 = nltk.word_tokenize(text3)
print(nltk.pos_tag(text3))
# Out:
# POS Tagging:
# [('Hello', 'NNP'), ('everyone', 'NN'), ('this', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('sample', 'JJ'), ('text', 'NN'), ('Earth', 'NN')]

# %%
# TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer
new_sentence = [
    "This is an example of term frequency meow meow meow"
]
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(new_sentence)
print("\nTF-IDF Matrix:")
print(tfidf.toarray())
print("\nFeature Names:")
print(vectorizer.get_feature_names_out())
# Out:
# TF-IDF Matrix:
# [[0.25 0.25 0.25 0.25 0.75 0.25 0.25 0.25]]
#
# Feature Names:
# ['an' 'example' 'frequency' 'is' 'meow' 'of' 'term' 'this']
